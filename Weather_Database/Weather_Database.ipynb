# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 749

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url ="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1899879f8f918c149e00ec4791ec6b7f

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']

        
        # Append the city information into the city_data list
        city_data.append({"City": city,
                         "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_weather_description,
                         })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | pozo colorado
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | oltedal
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | srednekolymsk
# Processing Record 9 of Set 1 | lesosibirsk
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | svetlogorsk
# Processing Record 12 of Set 1 | luderitz
# Processing Record 13 of Set 1 | praia da vitoria
# Processing Record 14 of Set 1 | walvis bay
# Processing Record 15 of Set 1 | bereda
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | san carlos de bariloche
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | khor
# Processing Record 22 of Set 1 | hofn
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | goderich
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 1 | saskylakh
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | novoalekseyevskaya
# Processing Record 31 of Set 1 | crotone
# Processing Record 32 of Set 1 | porto novo
# Processing Record 33 of Set 1 | kalmunai
# Processing Record 34 of Set 1 | hambantota
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | cam ranh
# Processing Record 37 of Set 1 | alexandria
# Processing Record 38 of Set 1 | bathsheba
# Processing Record 39 of Set 1 | tuktoyaktuk
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | lahaina
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | moerai
# Processing Record 46 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 1 | kodinsk
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | henties bay
# Processing Record 50 of Set 1 | los llanos de aridane
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | borujerd
# Processing Record 3 of Set 2 | georgetown
# Processing Record 4 of Set 2 | clarence town
# Processing Record 5 of Set 2 | homer
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | fare
# Processing Record 8 of Set 2 | mopti
# Processing Record 9 of Set 2 | kibala
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | ambilobe
# Processing Record 12 of Set 2 | kruisfontein
# Processing Record 13 of Set 2 | mahebourg
# Processing Record 14 of Set 2 | kapoeta
# Processing Record 15 of Set 2 | saint-philippe
# Processing Record 16 of Set 2 | byron bay
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | torbay
# Processing Record 20 of Set 2 | maragogi
# Processing Record 21 of Set 2 | lokachi
# Processing Record 22 of Set 2 | narsaq
# Processing Record 23 of Set 2 | vostok
# Processing Record 24 of Set 2 | pocatello
# Processing Record 25 of Set 2 | poum
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | codrington
# Processing Record 28 of Set 2 | nikolskoye
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | santo antonio do ica
# Processing Record 32 of Set 2 | camana
# Processing Record 33 of Set 2 | tandalti
# Processing Record 34 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 35 of Set 2 | port-cartier
# Processing Record 36 of Set 2 | hilo
# Processing Record 37 of Set 2 | catanduva
# Processing Record 38 of Set 2 | sitka
# Processing Record 39 of Set 2 | hami
# Processing Record 40 of Set 2 | mataura
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | tricase
# Processing Record 43 of Set 2 | gornopravdinsk
# Processing Record 44 of Set 2 | port lincoln
# Processing Record 45 of Set 2 | pierre
# Processing Record 46 of Set 2 | horsham
# Processing Record 47 of Set 2 | comodoro rivadavia
# Processing Record 48 of Set 2 | lagoa
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | vestmannaeyjar
# Processing Record 1 of Set 3 | pangnirtung
# Processing Record 2 of Set 3 | palmer
# Processing Record 3 of Set 3 | guadalupe y calvo
# Processing Record 4 of Set 3 | monitos
# Processing Record 5 of Set 3 | honiara
# Processing Record 6 of Set 3 | kavaratti
# Processing Record 7 of Set 3 | avarua
# Processing Record 8 of Set 3 | okhotsk
# Processing Record 9 of Set 3 | mareeba
# Processing Record 10 of Set 3 | detchino
# Processing Record 11 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 3 | askino
# Processing Record 13 of Set 3 | puerto madero
# Processing Record 14 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 15 of Set 3 | flinders
# Processing Record 16 of Set 3 | uberaba
# Processing Record 17 of Set 3 | gasa
# Processing Record 18 of Set 3 | ugoofaaru
# Processing Record 19 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 3 | panaba
# Processing Record 21 of Set 3 | lompoc
# Processing Record 22 of Set 3 | helong
# Processing Record 23 of Set 3 | ushi
# Processing Record 24 of Set 3 | pascagoula
# Processing Record 25 of Set 3 | iqaluit
# Processing Record 26 of Set 3 | jalu
# Processing Record 27 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 3 | tautira
# Processing Record 29 of Set 3 | chokurdakh
# Processing Record 30 of Set 3 | mattru
# Processing Record 31 of Set 3 | san patricio
# Processing Record 32 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 3 | urbana
# Processing Record 35 of Set 3 | el alto
# Processing Record 36 of Set 3 | thompson
# Processing Record 37 of Set 3 | chuy
# Processing Record 38 of Set 3 | montijo
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | salinopolis
# Processing Record 41 of Set 3 | shaowu
# Processing Record 42 of Set 3 | khatanga
# Processing Record 43 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 3 | banda aceh
# Processing Record 46 of Set 3 | beringovskiy
# Processing Record 47 of Set 3 | batagay
# Processing Record 48 of Set 3 | big bend
# Processing Record 49 of Set 3 | khandbari
# Processing Record 50 of Set 3 | jumla
# Processing Record 1 of Set 4 | aitape
# Processing Record 2 of Set 4 | axim
# Processing Record 3 of Set 4 | bani walid
# Processing Record 4 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 5 of Set 4 | thunder bay
# Processing Record 6 of Set 4 | puerto penasco
# Processing Record 7 of Set 4 | hithadhoo
# Processing Record 8 of Set 4 | narragansett
# Processing Record 9 of Set 4 | tasiilaq
# Processing Record 10 of Set 4 | fortuna
# Processing Record 11 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 12 of Set 4 | severo-kurilsk
# Processing Record 13 of Set 4 | clyde river
# Processing Record 14 of Set 4 | bisira
# Processing Record 15 of Set 4 | virginia beach
# Processing Record 16 of Set 4 | mastic beach
# Processing Record 17 of Set 4 | bambous virieux
# Processing Record 18 of Set 4 | bengkulu
# Processing Record 19 of Set 4 | imbituba
# Processing Record 20 of Set 4 | saldanha
# Processing Record 21 of Set 4 | korhogo
# Processing Record 22 of Set 4 | zyryanka
# Processing Record 23 of Set 4 | ventspils
# Processing Record 24 of Set 4 | beloha
# Processing Record 25 of Set 4 | romitan
# Processing Record 26 of Set 4 | berlevag
# Processing Record 27 of Set 4 | leningradskiy
# Processing Record 28 of Set 4 | pinega
# Processing Record 29 of Set 4 | rocha
# Processing Record 30 of Set 4 | norman wells
# Processing Record 31 of Set 4 | raga
# Processing Record 32 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 4 | arraial do cabo
# Processing Record 34 of Set 4 | talnakh
# Processing Record 35 of Set 4 | pevek
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | cabo san lucas
# Processing Record 38 of Set 4 | north bend
# Processing Record 39 of Set 4 | kirakira
# Processing Record 40 of Set 4 | mana
# Processing Record 41 of Set 4 | bambanglipuro
# Processing Record 42 of Set 4 | pacific grove
# Processing Record 43 of Set 4 | nemuro
# Processing Record 44 of Set 4 | qaanaaq
# Processing Record 45 of Set 4 | guanica
# Processing Record 46 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 4 | tuatapere
# Processing Record 48 of Set 4 | husavik
# Processing Record 49 of Set 4 | paldiski
# Processing Record 50 of Set 4 | sidi ali
# Processing Record 1 of Set 5 | fergus falls
# Processing Record 2 of Set 5 | alofi
# Processing Record 3 of Set 5 | nishihara
# Processing Record 4 of Set 5 | luena
# Processing Record 5 of Set 5 | port macquarie
# Processing Record 6 of Set 5 | carlsbad
# Processing Record 7 of Set 5 | kismayo
# Processing Record 8 of Set 5 | makakilo city
# Processing Record 9 of Set 5 | acapulco
# Processing Record 10 of Set 5 | bar harbor
# Processing Record 11 of Set 5 | bonfim
# Processing Record 12 of Set 5 | puerto escondido
# Processing Record 13 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 5 | geraldton
# Processing Record 15 of Set 5 | asyut
# Processing Record 16 of Set 5 | nanortalik
# Processing Record 17 of Set 5 | aden
# Processing Record 18 of Set 5 | airai
# Processing Record 19 of Set 5 | ayagoz
# Processing Record 20 of Set 5 | east london
# Processing Record 21 of Set 5 | saint-augustin
# Processing Record 22 of Set 5 | nitra
# Processing Record 23 of Set 5 | itarema
# Processing Record 24 of Set 5 | elliot lake
# Processing Record 25 of Set 5 | nioro
# Processing Record 26 of Set 5 | tiksi
# Processing Record 27 of Set 5 | cuamba
# Processing Record 28 of Set 5 | orebro
# Processing Record 29 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 5 | coquimbo
# Processing Record 31 of Set 5 | barreirinhas
# Processing Record 32 of Set 5 | dingle
# Processing Record 33 of Set 5 | kahului
# Processing Record 34 of Set 5 | thiruvananthapuram
# Processing Record 35 of Set 5 | maniitsoq
# Processing Record 36 of Set 5 | garissa
# Processing Record 37 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 5 | paciran
# Processing Record 39 of Set 5 | turayf
# Processing Record 40 of Set 5 | viedma
# Processing Record 41 of Set 5 | reykjavik
# Processing Record 42 of Set 5 | biysk
# Processing Record 43 of Set 5 | touros
# Processing Record 44 of Set 5 | fowa
# Processing Record 45 of Set 5 | floro
# Processing Record 46 of Set 5 | sur
# Processing Record 47 of Set 5 | faya
# Processing Record 48 of Set 5 | ulaangom
# Processing Record 49 of Set 5 | vila franca do campo
# Processing Record 50 of Set 5 | victoria
# Processing Record 1 of Set 6 | bafia
# Processing Record 2 of Set 6 | mogzon
# Processing Record 3 of Set 6 | yurginskoye
# Processing Record 4 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 6 | dinguiraye
# Processing Record 6 of Set 6 | avera
# Processing Record 7 of Set 6 | buraydah
# Processing Record 8 of Set 6 | castro
# Processing Record 9 of Set 6 | belmonte
# Processing Record 10 of Set 6 | teguise
# Processing Record 11 of Set 6 | carutapera
# Processing Record 12 of Set 6 | chuchkovo
# Processing Record 13 of Set 6 | kaitangata
# Processing Record 14 of Set 6 | gazanjyk
# Processing Record 15 of Set 6 | oksfjord
# Processing Record 16 of Set 6 | katsuura
# Processing Record 17 of Set 6 | the valley
# Processing Record 18 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 6 | ulaanbaatar
# Processing Record 20 of Set 6 | raudeberg
# Processing Record 21 of Set 6 | ancud
# Processing Record 22 of Set 6 | biltine
# Processing Record 23 of Set 6 | jucas
# Processing Record 24 of Set 6 | hamilton
# Processing Record 25 of Set 6 | punta alta
# Processing Record 26 of Set 6 | ribeira grande
# Processing Record 27 of Set 6 | stabat
# Processing Record 28 of Set 6 | constitucion
# Processing Record 29 of Set 6 | arkadelphia
# Processing Record 30 of Set 6 | camacupa
# Processing Record 31 of Set 6 | kyra
# Processing Record 32 of Set 6 | iwaki
# Processing Record 33 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 6 | huarmey
# Processing Record 35 of Set 6 | boende
# Processing Record 36 of Set 6 | pangody
# Processing Record 37 of Set 6 | nieuwpoort
# Processing Record 38 of Set 6 | pisco
# Processing Record 39 of Set 6 | udachnyy
# Processing Record 40 of Set 6 | klaksvik
# Processing Record 41 of Set 6 | saint anthony
# Processing Record 42 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 43 of Set 6 | vila velha
# Processing Record 44 of Set 6 | glendive
# Processing Record 45 of Set 6 | mandalgovi
# Processing Record 46 of Set 6 | bethel
# Processing Record 47 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 6 | vung tau
# Processing Record 49 of Set 6 | solnechnyy
# Processing Record 50 of Set 6 | tessalit
# Processing Record 1 of Set 7 | west wendover
# Processing Record 2 of Set 7 | mundi
# Processing Record 3 of Set 7 | moissala
# Processing Record 4 of Set 7 | carnarvon
# Processing Record 5 of Set 7 | lavrentiya
# Processing Record 6 of Set 7 | saint-pierre
# Processing Record 7 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 7 | fairbanks
# Processing Record 9 of Set 7 | saint george
# Processing Record 10 of Set 7 | mar del plata
# Processing Record 11 of Set 7 | artesia
# Processing Record 12 of Set 7 | ye
# City not found. Skipping...
# Processing Record 13 of Set 7 | caravelas
# Processing Record 14 of Set 7 | kollam
# Processing Record 15 of Set 7 | pietroasa
# Processing Record 16 of Set 7 | magadan
# Processing Record 17 of Set 7 | alyangula
# Processing Record 18 of Set 7 | yurimaguas
# Processing Record 19 of Set 7 | umm lajj
# Processing Record 20 of Set 7 | general pico
# Processing Record 21 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 22 of Set 7 | monrovia
# Processing Record 23 of Set 7 | miri
# Processing Record 24 of Set 7 | rio gallegos
# Processing Record 25 of Set 7 | mindelo
# Processing Record 26 of Set 7 | kiama
# Processing Record 27 of Set 7 | grand-santi
# Processing Record 28 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 7 | san quintin
# Processing Record 30 of Set 7 | tura
# Processing Record 31 of Set 7 | sinnamary
# Processing Record 32 of Set 7 | smithers
# Processing Record 33 of Set 7 | mouzakion
# City not found. Skipping...
# Processing Record 34 of Set 7 | duz
# City not found. Skipping...
# Processing Record 35 of Set 7 | longyearbyen
# Processing Record 36 of Set 7 | galle
# Processing Record 37 of Set 7 | koulikoro
# Processing Record 38 of Set 7 | zheleznogorsk
# Processing Record 39 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 7 | faranah
# Processing Record 41 of Set 7 | black diamond
# Processing Record 42 of Set 7 | polunochnoye
# Processing Record 43 of Set 7 | devonport
# Processing Record 44 of Set 7 | sabaudia
# Processing Record 45 of Set 7 | laguna
# Processing Record 46 of Set 7 | baruun-urt
# Processing Record 47 of Set 7 | odweyne
# Processing Record 48 of Set 7 | port-gentil
# Processing Record 49 of Set 7 | muros
# Processing Record 50 of Set 7 | kidal
# Processing Record 1 of Set 8 | kurumkan
# Processing Record 2 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 8 | onega
# Processing Record 4 of Set 8 | nhulunbuy
# Processing Record 5 of Set 8 | tucuman
# Processing Record 6 of Set 8 | yar-sale
# Processing Record 7 of Set 8 | male
# Processing Record 8 of Set 8 | san luis
# Processing Record 9 of Set 8 | qobustan
# Processing Record 10 of Set 8 | mayya
# Processing Record 11 of Set 8 | victorville
# Processing Record 12 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 8 | lapeer
# Processing Record 14 of Set 8 | port keats
# Processing Record 15 of Set 8 | souillac
# Processing Record 16 of Set 8 | nichinan
# Processing Record 17 of Set 8 | tadine
# Processing Record 18 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 19 of Set 8 | aguimes
# Processing Record 20 of Set 8 | itacarambi
# Processing Record 21 of Set 8 | mwense
# Processing Record 22 of Set 8 | pachora
# Processing Record 23 of Set 8 | jining
# Processing Record 24 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 8 | ayr
# Processing Record 26 of Set 8 | santa cruz de la palma
# Processing Record 27 of Set 8 | yellandu
# Processing Record 28 of Set 8 | faanui
# Processing Record 29 of Set 8 | kirensk
# Processing Record 30 of Set 8 | rizhao
# Processing Record 31 of Set 8 | kholtoson
# Processing Record 32 of Set 8 | kwinana
# Processing Record 33 of Set 8 | biak
# Processing Record 34 of Set 8 | xining
# Processing Record 35 of Set 8 | camacha
# Processing Record 36 of Set 8 | mount isa
# Processing Record 37 of Set 8 | hendijan
# City not found. Skipping...
# Processing Record 38 of Set 8 | russell
# Processing Record 39 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 40 of Set 8 | ciocarlia
# Processing Record 41 of Set 8 | jacksonville
# Processing Record 42 of Set 8 | ivanivka
# Processing Record 43 of Set 8 | meridian
# Processing Record 44 of Set 8 | eureka
# Processing Record 45 of Set 8 | uray
# Processing Record 46 of Set 8 | nanakuli
# Processing Record 47 of Set 8 | lubao
# Processing Record 48 of Set 8 | langham
# Processing Record 49 of Set 8 | casablanca
# Processing Record 50 of Set 8 | tommot
# Processing Record 1 of Set 9 | osa
# Processing Record 2 of Set 9 | karachi
# Processing Record 3 of Set 9 | zhigansk
# Processing Record 4 of Set 9 | kendari
# Processing Record 5 of Set 9 | port blair
# Processing Record 6 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 7 of Set 9 | igrim
# Processing Record 8 of Set 9 | mackay
# Processing Record 9 of Set 9 | sioux lookout
# Processing Record 10 of Set 9 | berdigestyakh
# Processing Record 11 of Set 9 | inuvik
# Processing Record 12 of Set 9 | olafsvik
# Processing Record 13 of Set 9 | penhold
# Processing Record 14 of Set 9 | ashington
# Processing Record 15 of Set 9 | ilo
# Processing Record 16 of Set 9 | rawson
# Processing Record 17 of Set 9 | aklavik
# Processing Record 18 of Set 9 | daru
# Processing Record 19 of Set 9 | broome
# Processing Record 20 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 9 | ha giang
# Processing Record 22 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 9 | ponta delgada
# Processing Record 24 of Set 9 | galeana
# Processing Record 25 of Set 9 | bria
# Processing Record 26 of Set 9 | namibe
# Processing Record 27 of Set 9 | ndago
# Processing Record 28 of Set 9 | trenggalek
# Processing Record 29 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 30 of Set 9 | alihe
# Processing Record 31 of Set 9 | goya
# Processing Record 32 of Set 9 | korla
# Processing Record 33 of Set 9 | dunedin
# Processing Record 34 of Set 9 | kumluca
# Processing Record 35 of Set 9 | mandiana
# Processing Record 36 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 9 | pithoragarh
# Processing Record 38 of Set 9 | hasaki
# Processing Record 39 of Set 9 | little current
# Processing Record 40 of Set 9 | ust-tsilma
# Processing Record 41 of Set 9 | cidreira
# Processing Record 42 of Set 9 | burnie
# Processing Record 43 of Set 9 | nizwa
# Processing Record 44 of Set 9 | kuusamo
# Processing Record 45 of Set 9 | pochutla
# Processing Record 46 of Set 9 | nome
# Processing Record 47 of Set 9 | aykhal
# Processing Record 48 of Set 9 | cayenne
# Processing Record 49 of Set 9 | prince rupert
# Processing Record 50 of Set 9 | xiongyue
# Processing Record 1 of Set 10 | bridlington
# Processing Record 2 of Set 10 | isangel
# Processing Record 3 of Set 10 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 4 of Set 10 | looc
# Processing Record 5 of Set 10 | chirnogeni
# Processing Record 6 of Set 10 | kolyvan
# Processing Record 7 of Set 10 | murakami
# Processing Record 8 of Set 10 | aginskoye
# Processing Record 9 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 10 | constantine
# Processing Record 11 of Set 10 | kinsale
# Processing Record 12 of Set 10 | acajutla
# Processing Record 13 of Set 10 | olavarria
# Processing Record 14 of Set 10 | sayabec
# City not found. Skipping...
# Processing Record 15 of Set 10 | olinda
# Processing Record 16 of Set 10 | waipawa
# Processing Record 17 of Set 10 | parau
# Processing Record 18 of Set 10 | bintulu
# Processing Record 19 of Set 10 | ichinohe
# Processing Record 20 of Set 10 | jacareacanga
# Processing Record 21 of Set 10 | manaus
# Processing Record 22 of Set 10 | huntington
# Processing Record 23 of Set 10 | lorengau
# Processing Record 24 of Set 10 | kysyl-syr
# Processing Record 25 of Set 10 | denia
# Processing Record 26 of Set 10 | venice
# Processing Record 27 of Set 10 | maxixe
# Processing Record 28 of Set 10 | aguas vermelhas
# Processing Record 29 of Set 10 | seoul
# Processing Record 30 of Set 10 | lucapa
# Processing Record 31 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 32 of Set 10 | maringa
# Processing Record 33 of Set 10 | kutum
# Processing Record 34 of Set 10 | masallatah
# Processing Record 35 of Set 10 | thayetmyo
# Processing Record 36 of Set 10 | three hills
# Processing Record 37 of Set 10 | natal
# Processing Record 38 of Set 10 | privokzalnyy
# City not found. Skipping...
# Processing Record 39 of Set 10 | avila
# Processing Record 40 of Set 10 | campo grande
# Processing Record 41 of Set 10 | miranda
# Processing Record 42 of Set 10 | eyl
# Processing Record 43 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 10 | la sarre
# Processing Record 45 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 46 of Set 10 | hervey bay
# Processing Record 47 of Set 10 | boqueirao
# Processing Record 48 of Set 10 | kailua
# Processing Record 49 of Set 10 | la ronge
# Processing Record 50 of Set 10 | kavieng
# Processing Record 1 of Set 11 | poopo
# Processing Record 2 of Set 11 | saquena
# Processing Record 3 of Set 11 | jamshedpur
# Processing Record 4 of Set 11 | hampton
# Processing Record 5 of Set 11 | duluth
# Processing Record 6 of Set 11 | flin flon
# Processing Record 7 of Set 11 | arman
# Processing Record 8 of Set 11 | kaeo
# Processing Record 9 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 11 | ludvika
# Processing Record 11 of Set 11 | alugan
# Processing Record 12 of Set 11 | chapais
# Processing Record 13 of Set 11 | sunbury
# Processing Record 14 of Set 11 | nakhon phanom
# Processing Record 15 of Set 11 | ahipara
# Processing Record 16 of Set 11 | kytlym
# City not found. Skipping...
# Processing Record 17 of Set 11 | egvekinot
# Processing Record 18 of Set 11 | salalah
# Processing Record 19 of Set 11 | fort nelson
# Processing Record 20 of Set 11 | manggar
# Processing Record 21 of Set 11 | havre
# Processing Record 22 of Set 11 | inta
# Processing Record 23 of Set 11 | hirara
# Processing Record 24 of Set 11 | naze
# Processing Record 25 of Set 11 | samana
# Processing Record 26 of Set 11 | gat
# Processing Record 27 of Set 11 | sao filipe
# Processing Record 28 of Set 11 | las vegas
# Processing Record 29 of Set 11 | omidiyeh
# Processing Record 30 of Set 11 | green river
# Processing Record 31 of Set 11 | afmadu
# City not found. Skipping...
# Processing Record 32 of Set 11 | vrangel
# Processing Record 33 of Set 11 | asau
# Processing Record 34 of Set 11 | esna
# Processing Record 35 of Set 11 | mehamn
# Processing Record 36 of Set 11 | waddan
# Processing Record 37 of Set 11 | chavinda
# Processing Record 38 of Set 11 | port hedland
# Processing Record 39 of Set 11 | beni
# Processing Record 40 of Set 11 | cheyenne
# Processing Record 41 of Set 11 | komsomolskiy
# Processing Record 42 of Set 11 | steinheim
# Processing Record 43 of Set 11 | doha
# Processing Record 44 of Set 11 | rochester
# Processing Record 45 of Set 11 | dali
# Processing Record 46 of Set 11 | eenhana
# Processing Record 47 of Set 11 | chitrakonda
# Processing Record 48 of Set 11 | vilyuysk
# Processing Record 49 of Set 11 | guerrero negro
# Processing Record 50 of Set 11 | vigrestad
# Processing Record 1 of Set 12 | ornskoldsvik
# Processing Record 2 of Set 12 | lazaro cardenas
# Processing Record 3 of Set 12 | ordubad
# Processing Record 4 of Set 12 | burica
# City not found. Skipping...
# Processing Record 5 of Set 12 | yulara
# Processing Record 6 of Set 12 | logansport
# Processing Record 7 of Set 12 | qasigiannguit
# Processing Record 8 of Set 12 | corowa
# Processing Record 9 of Set 12 | guiratinga
# Processing Record 10 of Set 12 | amari
# Processing Record 11 of Set 12 | belyy yar
# Processing Record 12 of Set 12 | ilulissat
# Processing Record 13 of Set 12 | opuwo
# Processing Record 14 of Set 12 | aksarayskiy
# Processing Record 15 of Set 12 | kiruna
# Processing Record 16 of Set 12 | nanga eboko
# Processing Record 17 of Set 12 | victor harbor
# Processing Record 18 of Set 12 | champa
# Processing Record 19 of Set 12 | pechea
# Processing Record 20 of Set 12 | siverek
# Processing Record 21 of Set 12 | inhambane
# Processing Record 22 of Set 12 | valdivia
# Processing Record 23 of Set 12 | sisimiut
# Processing Record 24 of Set 12 | svaty jur
# Processing Record 25 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 12 | culebra
# Processing Record 27 of Set 12 | zhangye
# Processing Record 28 of Set 12 | benguela
# Processing Record 29 of Set 12 | ulma
# Processing Record 30 of Set 12 | yerbogachen
# Processing Record 31 of Set 12 | a
# City not found. Skipping...
# Processing Record 32 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 33 of Set 12 | hohhot
# Processing Record 34 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 12 | pocone
# Processing Record 36 of Set 12 | ustka
# Processing Record 37 of Set 12 | savinka
# Processing Record 38 of Set 12 | grindavik
# Processing Record 39 of Set 12 | qibili
# City not found. Skipping...
# Processing Record 40 of Set 12 | oktyabrskoye
# Processing Record 41 of Set 12 | pangai
# Processing Record 42 of Set 12 | venezuela
# Processing Record 43 of Set 12 | honningsvag
# Processing Record 44 of Set 12 | konskie
# Processing Record 45 of Set 12 | mount gambier
# Processing Record 46 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 12 | buchanan
# Processing Record 48 of Set 12 | aksarka
# Processing Record 49 of Set 12 | rorvik
# Processing Record 50 of Set 12 | canto do buriti
# Processing Record 1 of Set 13 | pampa
# Processing Record 2 of Set 13 | paamiut
# Processing Record 3 of Set 13 | dwarka
# Processing Record 4 of Set 13 | pak phanang
# Processing Record 5 of Set 13 | kayseri
# Processing Record 6 of Set 13 | arroio dos ratos
# Processing Record 7 of Set 13 | sambava
# Processing Record 8 of Set 13 | ketchikan
# Processing Record 9 of Set 13 | emba
# Processing Record 10 of Set 13 | yerkoy
# Processing Record 11 of Set 13 | ibra
# Processing Record 12 of Set 13 | osypenko
# Processing Record 13 of Set 13 | bonavista
# Processing Record 14 of Set 13 | belle fourche
# Processing Record 15 of Set 13 | englewood
# Processing Record 16 of Set 13 | bandarbeyla
# Processing Record 17 of Set 13 | conceicao da barra
# Processing Record 18 of Set 13 | sao bento
# Processing Record 19 of Set 13 | bud
# Processing Record 20 of Set 13 | fort smith
# Processing Record 21 of Set 13 | kulhudhuffushi
# Processing Record 22 of Set 13 | marovoay
# Processing Record 23 of Set 13 | bilma
# Processing Record 24 of Set 13 | samarai
# Processing Record 25 of Set 13 | thinadhoo
# Processing Record 26 of Set 13 | damghan
# Processing Record 27 of Set 13 | vila
# Processing Record 28 of Set 13 | marawi
# Processing Record 29 of Set 13 | ascension
# Processing Record 30 of Set 13 | havelock
# Processing Record 31 of Set 13 | tavda
# Processing Record 32 of Set 13 | kieta
# Processing Record 33 of Set 13 | berezovyy
# Processing Record 34 of Set 13 | luwuk
# Processing Record 35 of Set 13 | lydenburg
# Processing Record 36 of Set 13 | ukiah
# Processing Record 37 of Set 13 | auki
# Processing Record 38 of Set 13 | grand gaube
# Processing Record 39 of Set 13 | beshpagir
# Processing Record 40 of Set 13 | whitehorse
# Processing Record 41 of Set 13 | ottawa
# Processing Record 42 of Set 13 | sao felix do xingu
# Processing Record 43 of Set 13 | ayan
# Processing Record 44 of Set 13 | sao joao da barra
# Processing Record 45 of Set 13 | galdar
# Processing Record 46 of Set 13 | cockburn town
# Processing Record 47 of Set 13 | aranos
# Processing Record 48 of Set 13 | oda
# Processing Record 49 of Set 13 | ust-kulom
# Processing Record 50 of Set 13 | ngunguru
# Processing Record 1 of Set 14 | rio grande
# Processing Record 2 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 3 of Set 14 | bilibino
# Processing Record 4 of Set 14 | kikwit
# Processing Record 5 of Set 14 | portland
# Processing Record 6 of Set 14 | oranjestad
# Processing Record 7 of Set 14 | saint-joseph
# Processing Record 8 of Set 14 | qurayyat
# Processing Record 9 of Set 14 | ixtapa
# Processing Record 10 of Set 14 | riyadh
# Processing Record 11 of Set 14 | channel-port aux basques
# Processing Record 12 of Set 14 | gladstone
# Processing Record 13 of Set 14 | adrar
# Processing Record 14 of Set 14 | pontianak
# Processing Record 15 of Set 14 | gland
# Processing Record 16 of Set 14 | trairi
# Processing Record 17 of Set 14 | novouzensk
# Processing Record 18 of Set 14 | general roca
# Processing Record 19 of Set 14 | torres
# Processing Record 20 of Set 14 | huicheng
# Processing Record 21 of Set 14 | takob
# City not found. Skipping...
# Processing Record 22 of Set 14 | basoko
# Processing Record 23 of Set 14 | kihei
# Processing Record 24 of Set 14 | ternate
# Processing Record 25 of Set 14 | gamba
# Processing Record 26 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 27 of Set 14 | prochnookopskaya
# Processing Record 28 of Set 14 | pindi gheb
# Processing Record 29 of Set 14 | zapolyarnyy
# Processing Record 30 of Set 14 | pita
# Processing Record 31 of Set 14 | karratha
# Processing Record 32 of Set 14 | shihezi
# Processing Record 33 of Set 14 | leshukonskoye
# Processing Record 34 of Set 14 | deer lake
# Processing Record 35 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 36 of Set 14 | sechura
# Processing Record 37 of Set 14 | bingol
# Processing Record 38 of Set 14 | chulym
# Processing Record 39 of Set 14 | haines junction
# Processing Record 40 of Set 14 | birao
# Processing Record 41 of Set 14 | maloy
# Processing Record 42 of Set 14 | emerald
# Processing Record 43 of Set 14 | mao
# Processing Record 44 of Set 14 | redmond
# Processing Record 45 of Set 14 | urusha
# Processing Record 46 of Set 14 | oistins
# Processing Record 47 of Set 14 | huilong
# Processing Record 48 of Set 14 | namatanai
# Processing Record 49 of Set 14 | deputatskiy
# Processing Record 50 of Set 14 | shakawe
# Processing Record 1 of Set 15 | labuhan
# Processing Record 2 of Set 15 | itupeva
# Processing Record 3 of Set 15 | arcata
# Processing Record 4 of Set 15 | cartagena
# Processing Record 5 of Set 15 | hobyo
# Processing Record 6 of Set 15 | simitli
# Processing Record 7 of Set 15 | ishigaki
# Processing Record 8 of Set 15 | inndyr
# Processing Record 9 of Set 15 | dakar
# Processing Record 10 of Set 15 | sogdiondon
# City not found. Skipping...
# Processing Record 11 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 15 | sahrak
# City not found. Skipping...
# Processing Record 13 of Set 15 | chipinge
# Processing Record 14 of Set 15 | norden
# Processing Record 15 of Set 15 | te anau
# Processing Record 16 of Set 15 | bekwai
# Processing Record 17 of Set 15 | oudtshoorn
# Processing Record 18 of Set 15 | amazar
# Processing Record 19 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 20 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 21 of Set 15 | lufilufi
# Processing Record 22 of Set 15 | kapit
# Processing Record 23 of Set 15 | iralaya
# Processing Record 24 of Set 15 | riberalta
# Processing Record 25 of Set 15 | zima
# Processing Record 26 of Set 15 | bitung
# Processing Record 27 of Set 15 | ondjiva
# Processing Record 28 of Set 15 | kizu
# City not found. Skipping...
# Processing Record 29 of Set 15 | sipka
# City not found. Skipping...
# Processing Record 30 of Set 15 | port moresby
# Processing Record 31 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 15 | puerto colombia
# Processing Record 33 of Set 15 | mikhaylovka
# Processing Record 34 of Set 15 | mitu
# Processing Record 35 of Set 15 | pahalgam
# Processing Record 36 of Set 15 | siuna
# Processing Record 37 of Set 15 | arua
# Processing Record 38 of Set 15 | salihli
# Processing Record 39 of Set 15 | micheweni
# Processing Record 40 of Set 15 | domoni
# Processing Record 41 of Set 15 | tunghsiao
# City not found. Skipping...
# Processing Record 42 of Set 15 | voerde
# Processing Record 43 of Set 15 | saint-marc-des-carrieres
# Processing Record 44 of Set 15 | kasongo-lunda
# Processing Record 45 of Set 15 | berberati
# Processing Record 46 of Set 15 | tsaratanana
# Processing Record 47 of Set 15 | acarau
# Processing Record 48 of Set 15 | barra do corda
# Processing Record 49 of Set 15 | aswan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 675

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  mount gambier      AU -37.8333  140.7667     69.51        46          90
# 1          vaini      TO -21.2000 -175.2000     82.56        78          20
# 2     georgetown      MY   5.4112  100.3354     84.24        82          20
# 3      hai duong      VN  20.9333  106.3167     80.60        35          67
# 4          bluff      NZ -46.6000  168.3333     48.02        70          60
# 5        kodinsk      RU  58.6881   99.1844     35.31        98         100
# 6        rikitea      PF -23.1203 -134.9692     68.67        70          82
# 7     chokurdakh      RU  70.6333  147.9167     16.18        95          99
# 8  cockburn town      TC  21.4612  -71.1419     81.68        75           2
# 9         hobart      AU -42.8794  147.3294     63.27        54          75
#
#    Wind Speed Current Description
# 0        6.02     overcast clouds
# 1       10.36          few clouds
# 2        2.30       moderate rain
# 3       19.89       broken clouds
# 4       23.91       broken clouds
# 5        4.00          light snow
# 6       22.75       broken clouds
# 7        8.55     overcast clouds
# 8       10.76           clear sky
# 9        5.75       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity',  'Cloudiness', 'Wind Speed',  'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]


# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         kodiak      US  57.7900 -152.4072     45.91        81         100
# 1         barrow      US  71.2906 -156.7887     26.62        93         100
# 2  pozo colorado      PY -23.4923  -58.7972     70.86        86          88
# 3      upernavik      GL  72.7868  -56.1549     25.74        92         100
# 4        oltedal      NO  58.8310    6.0466     44.19        95          69
# 5         atuona      PF  -9.8000 -139.0333     77.16        69           0
# 6  srednekolymsk      RU  67.4500  153.6833     12.56        80         100
# 7    lesosibirsk      RU  58.2358   92.4828     34.05        99         100
# 8         albany      US  42.6001  -73.9662     43.21        87          36
# 9    svetlogorsk      BY  52.6333   29.7333     47.64        92         100
#
#    Wind Speed Current Description
# 0       17.27          light rain
# 1       16.11     overcast clouds
# 2        3.71     overcast clouds
# 3        8.61          light snow
# 4        3.74       broken clouds
# 5       13.02           clear sky
# 6       20.47     overcast clouds
# 7        1.43     overcast clouds
# 8        3.65    scattered clouds
# 9        4.92     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
